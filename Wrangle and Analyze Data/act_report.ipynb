# %% [markdown]
# # Act Report

# %% [markdown]
#     This Project is based on Twitter account for @WeRateDogs, which seems to use a humorous wording describing all rating and used unusual rating method where dogs are rated on a scale of 10 but more than 10.
#     We need to gather data from three different sources, assess, clean and visualize the trend.
#
#     This company was start by college graduate Matt Nelson , He was called "the Internet's most famous dog rater" by the Washington Post. His success with WeRateDogsTM has been documented in Esquire, NY Mag, Buzzfeed, Huffington Post, Daily Mail, People magazine, Study Breaks, and many more. The Washington Post called him “the Internet’s most famous dog rater.” Nelson accumulated millions of followers across Twitter, Facebook, Instagram, and Snapchat in less than a year by showcasing user- submitted dog media attached to his trademark caption style, and has since grown to over four million combined followers. He resides in Charleston, West Virginia.
#     There were 2300+ observations but cleaning process reduced it to 1900+ observations. While working on the project, I understood why data wrangling is important as lot of observation are repetitive, inappropriate, incomplete and messy. I have cleaned up 8 quality issues and 2 tidiness issues so I can say I have completed major process of accessing and cleaning somewhat but it’s not perfectly cleaned.
#     During analysis I found retweets and favourites have strong correlation beacuse its how twitter works. If tweet gets more likes then it tends to be viral post soon therefore counts increase rapidly.

# %%
from PIL import Image

Image.open('Fav vs Retweet.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=576x360 at 0x7F55D3FC2CF8>

# %% [markdown]
#     In the below plot, it is clear that as time passes trends grows strongly.

# %%
Image.open('Fav tweets over year.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=576x360 at 0x7F55D3FC2DA0>
